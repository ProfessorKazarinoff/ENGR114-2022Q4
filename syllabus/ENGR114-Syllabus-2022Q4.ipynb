# %% [markdown]
# # ENGR114 Syllabus 2022Q4

# %% [markdown]
# ## Welcome
#
# Welcome to ENGR114 Engineering Programming! I’m your instructor Peter. I’m here to help guide you through learning how to solve engineering problems with programming. I’m excited to work with you this quarter. I strive to create a safe and nurturing learning environment for all students.
#
# This syllabus introduces you to the goals of the course and how we will be working together this term.

# %% [markdown]
# ## Course Information
#
# College: Portland Community College
#
# Course: ENGR114
#
# Term and Year: Fall 2022
#
# CRN: 45404
#
# Meeting Day / Time / Location:
#
# Mon 9:00am - 11:50am in AM107 on the PCC Sylvania Campus
#
# Wed 9:00am - 11:50am in AM107 on the PCC Sylvania Campus
#
# Credits: 4
#
# Prerequisites: ENGR101 (or department approved equivalent)
#
# Transfer Information: This course transfers as part of PSU's 1st year Engineering Sequence, OSU's 1st year Engineering Sequence and OIT's 1st year Engineering Sequence. All Engineering Transfer students should take this course. For more information see: [https://www.pcc.edu/programs/engineering/course-plan/](https://www.pcc.edu/programs/engineering/course-plan/)

# %% [markdown]
# ## Instructor Information
#
#  * Instructor: Peter Kazarinoff
#  * Instructor email: peter.kazarinoff@pcc.edu
#  * Office Hours: Thurs 11:00am-12:00pm and Fri 11:00am-12:00pm meet in-person in TCB314 or online. Schedule an appointment: [Office Hours Appointment Slots](#)
#  * Office Location: SY TCB 314
#  * Office Phone: 971-722-8065

# %% [markdown]
# ## Course Description
#
# This course introduces computer programming terminology and techniques as applied to specific engineering applications. Topics include electrical circuit analysis, audio signal processing, image processing, and interfacing with hardware such as microcontrollers and analog-to-digital convert- ers application. The course covers reading and documenting code, running and testing code, and debugging and correcting defects found in code.
#
# Course Content and Outline Guide: [https://www.pcc.edu/ccog/?fa=ccog&subject=ENGR&course=114](https://www.pcc.edu/ccog/?fa=ccog&subject=ENGR&course=114)

# %% [markdown]
# ## Instructional Materials
#
# ### Class Website
#
# D2L. The D2L learning management system is used to post homework assignments, lecture materials, labs, and exams. Your course work, including: homework, labs, quizzes, exams and projects need to be submitted to D2L. All course grades will be recorded in D2L.
#
# ### Textbook
#
# _Problem Solving with Python 3.7 Edition_ by Peter D. Kazarinoff. Available on-line at: [problemsolvingwithpython.com](#) and hard copy on Amazon.com: [https://www.amazon.com/dp/1693405415](https://www.amazon.com/dp/1693405415). Ensure you have the 3.7 Edition. Homework will be assigned out of the book.
#
# ### Computers
#
# This course is taught in-person in a computer lab. Students do not need to have access to their own computer to complete the course. All PCC computer labs will have access to the necessary software. Although not required, you may use your own computer instead of the lab computers if desired.
#
# ### Software
#
# Access to the course programming language - Python. We will use the version of Python installed on the computers in AM107. Although not required, you can install Python locally on your own Windows or MacOS computer. Find the installer at [https://anaconda.com/distribution](https://anaconda.com/distribution). Alternatively, can also use Google CoLab [https://colab.research.google.com](https://colab.research.google.com) with your ```@pcc.edu``` account using a web browser connected to the internet.

# %% [markdown]
# ## Course Components
#
# ### Homework
#
# Homework is intended as a means of practicing the concepts presented in class. It is advised that you keep up with your homework assignments each week and submit each week’s assignment to D2L. Homework will be reviewed by your instructor to determine which topics need more reinforcement and as a way for you and your instructor to share your course progress. Homework will not be included in your grades and homework due dates will not be enforced by grading.
#
# ### Labs
#
# Typically, lecture is held early in the week and lab held later in the week. Lab assignments are typically due at the end of the lab period, uploaded to D2L. Your median lab score (your middle lab score, not your average lab score) will be used to calculate your final grade. Lab assignments can be re-done and re-submitted to improve your grade. All lab re-submissions must be uploaded to D2L by Monday at 12noon, the last week of the quarter (the Monday before finals week). No labs submitted after this date will be evaluated for course credit. This enforced due date ensures your instructor has time to grade your lab assignments before the end of the quarter.
#
# ### Exams
#
# If a student is unable to take the exam when it is scheduled, it is the student’s responsibility to notify the instructor at least 1 week prior to the date of an exam. Make-up exams, if allowed, will be scheduled by the instructor after consulting with the student prior to the original date of the exam. I look forward to working with any students who have testing accommodations. It is the student’s responsibility to set up a meeting at least 1 week prior to the exam date to review exam protocol. There will be two Exams in the course: one Midterm Exam and one Final Exam.
#
# #### Exam Deadlines and Grading:
#
#  * Exams can be completed at any time during the week the exam is posted. Once you open the exam in D2L, you have 3 hours to complete the exam and upload your exam to D2L.
#  * Exam uploads after the deadline posted in D2L will receive a 0 (Insufficient evidence).
#
#  * You can re-do your Exam 1. Exam 1 re-dos are due by the last week of the quarter, Monday at 12noon. No Exam 1 re-do’s will be accepted after this due date for a grade in order to give your instructor sufficient time to grade your Exam 1 re-dos by the end of the quarter.
#
#  * Exams which contain coppied work of others will recieve a 0 (insufficient evidence). The instructor can not assess student learning when a student submits someone else’s work. A student who recieves a 0 (insufficient evidence) on Exam 1 must complete an Exam 1 re-do by the last week of the quarter, Monday at 12noon.
#
#  * There will be no Exam 2 re-do’s.
#
# ### In-Class Assignments
#
# Most lecture days include an in-class practice that should to be uploaded to D2L by the end of the class period. See D2L for specific in-class practice details. In-class practice will not be graded. Use in-class practice to track your progress in the course and guage your participation in the course. In-class assign- ments will not be included in your grades and in-class assignment due dates will not be enforced by grading.

# %% [markdown]
# ## Grading
#
# ### Grade Distribution
#
#  * Homework: 0%
#  * In-class: 0%
#  * Labs: 30%
#  * Exam 1: 35%
#  * Exam 2: 35%
#
# Grades in the course will follow a 4-point grading scale:
#
# 4 - Exceeds standards
#
# 3 - Meets standards
#
# 2 - Approaches standards
#
# 1 - Not yet met standards
#
# 0 - Insufficient evidence
#
# ### Grade Conversions
#
# Final grades will be mapped from the 4-point scale to letter grades at the end of the quarter as follows:
#
# | 4-point scale | Letter grade |
# | --- | --- |
# | 3.00 - 4.00 | A |
# | 2.00 - 2.99 |	B |
# | 1.00 - 1.99 | C |
# | 0.01 - 0.99 | D |
# | 0.00 | F |
#
# ### Attendance
#
# Attendance is not graded, but as your instructor, I encourage you to attend all scheduled classes.
#
# ### Make-up Policy
#
# Missing class may result in missing assignments completed during that class. Please see your instructor for specifics on the make-up policy.
#
# ### Grade Details
#
# To receive a Pass in the course, a grade of C or better must be earned. Instructor may adjust these cutoffs at their discretion based on overall class performance. Please note that D, F, P/NP, AUD grades do not meet prerequisite requirements and are not transferable to 4-year Oregon Engineering Colleges and Universities. An I (Incomplete) grade is reserved for students who have completed a majority of the course requirements and for reasons acceptable to the instructor, cannot complete the course. A written request, signed by the instructor and student, stating the reasons for the incomplete and a schedule for completing course requirements must be filed in the Engineering Office. Note that an I may impact financial aid. See PCC's Grading Guidelines: [https://pcc.edu/student-records/grading/](https://pcc.edu/student-records/grading/)

# %% [markdown]
# ## Tentative Course Schedule
#
# The course schedule below is subject to change. Check D2L for specific course deadlines.
#
# | Week | Lecture | Lab | Homework |
# | --- | --- | --- | --- | --- |
# | Week 1 | The Python REPL | Lab 1: Circuit Python |
# | Week 2 | Data types and variables | Lab 2: Data Types | Homework 1 |
# | Week 3 | No Class - Holiday | Lab 3: Weather Data | Homework 2 |
# | Week 4 | Plotting | Lab 4: Plotting | Homework 3 |
# | Week 5 | Functions | Lab 5: Web API’s | Homework 4 |
# | Week 6 | Review | **Exam 1** |
# | Week 7 | If, elif, else | Lab 6: Image Editing | Homework 5 |
# | Week 8 | For Loops | Lab 7: External Hardware | Homework 6 |
# | Week 9 | While Loops | Lab 8: Taylor Series | Homework 7 |
# | Week 10 |	Exam 2 Drafts | Complete Exam 2	|
# | Finals Week |	**Exam 2 Delivery** | | |
#
# ### Important Due Dates
#
#  * Exam 1:
#  * Exam 2:
#
# ### Drop / Withdraw Deadlines
#
# PCC's Add, Drop, and Withdraw deadlines can be found here: [(https://pcc.edu/enroll/registration/dropping.html)]((https://pcc.edu/enroll/registration/dropping.html))

# %% [markdown]
# ## Information for Students
#
# ### PCC’s Statement on a Culture of Equity, Diversity, & Inclusion
#
# PCC promotes the success, dignity, and worth of each individual by providing a safe environment where the examination of divergent ideas, experiences and systems of inequality adds depth to the learning experience. PCC strives to provide opportunity to all students and support services to ensure the highest level of success.
#
# ### Accessibility and Accommodations
#
# PCC is committed to ensuring that classes are accessible. Disability
# Services [www.pcc.edu/disability/] works with students and faculty to minimize barriers. If students elect to use approved academic accommodations, they must provide in advance formal notification from Disability Services to the instructor.You can reach the Office for Students with Disabilities (OSD) at (971) 722-4341.
#
# ### Student Rights & Responsibilities
#
# The Student Rights and Responsibilities Handbook ([https://www.pcc.edu/about/policy/student-rights/](https://www.pcc.edu/about/policy/student-rights/)) establishes students' freedoms and protections as well as expectations of appropriate behavior and ethical academic work. The Handbook includes items such as the Policy on Student Rights, the Policy on Student Conduct, and the Academic Integrity Policy.
#
# ### Class Rules
#
# Be respectful and courteous to others. This courtesy applies during class Zoom meetings and Zoom chat. In D2L, provide respectful communication to your fellow students. The instructor strives to ensure there is a safe and supportive learning environment for all students in the course.
#
# ### Flexibility
#
# The instructor may revise the class calendar, modify content, and/or substitute assignments in response to institutional, weather, or class situations.
#
# ### Title IX Statement
#
# PCC is committed to creating and fostering a learning and working environment based on open communication and mutual respect. If you believe you have encountered sexual harassment, sexual misconduct, sexual assault, or discrimination based on race, color, religion, age, national origin, veteran status, sex, sexual orientation, gender identity, or disability please contact the Office of Equity and Inclusion at (971) 722-5840 or equity.inclusion@pcc.edu.
#
# ### Food & Housing Insecurity
#
# PCC wants you to be successful and offers some resources that may help: Emergency Funds ([https://pcc.edu/enroll/paying-forcollege/emergency-funds.html](https://pcc.edu/enroll/paying-forcollege/emergency-funds.html)) and food pantries ([https://pcc.edu/studentleadership/services/free-resources/](https://pcc.edu/studentleadership/services/free-resources/)). You can also contact a campus Student Conduct and Retention Coordinator ([https://pcc.edu/student-conduct/care/](https://pcc.edu/student-conduct/care/)).
#
# ### PCC is a Sanctuary College
#
# PCC is a sanctuary college. For more information and resources see: [https://pcc.edu/resources/undocumented-students/](https://pcc.edu/resources/undocumented-students/).
#
# ### Attendance, Make-Up, and Other Class Policies
#
# Attendance at all lecture and lab meetings will be tracked, but is not required. Attendace will not be included in your final course grade. Poor attendance or repeated tardiness will have an adverse effect on student learning. Students should check their ```@pcc.edu``` email at least three times a week to ensure receipt of announcements and essential information about the class. Students may only attend this course if registered. Students who are unable to attend must drop the course through the PCC Registration Office. To remove tuition charges, the course must be dropped by the student before the drop deadline posted on MyPCC. Students who never attend, or stop attending, without dropping may receive a W or a failing grade and will be required to pay for the course.
#
# ### Additional Course Resources
#
#  * _Think Python_ is a free textbook in PDF form, and is available for purchase in print form from Amazon.
#
#  * _Get Programming_ by Ana Bell is another good book. It is available at Manning Publications.
#
#  * _Python Basics_ by the Real Python team has a few free chapters that could be useful.
#
#  * I blog at [https://pythonforundergradengineers.com](https://pythonforundergradengineers.com) which has additional tutorials, and Python tips and tricks.
#
# ### Student services:
#
#  * Veteran Resources
#  * Sylvania Student Learning Center
#  * Sylvania Women’s Resource Center
#  * LGBTQ Resources and Programming at Sylvania
#
# ### Academic Integrity
#
# Students are required to complete this course in accordance with the PCC Student Rights and Responsibilities Handbook. Dishonest activities such as cheating on exams and submitting or copying work done by others will result in disciplinary actions including, but not limited to, receiving a failing grade in the course.

# %% [markdown]
# ### A Final Note
#
# Thank you for reading this all the way to the end. If you have questions, comments, or concerns please let your instructor know. We are here to support you. At the end of the quarter, please fill out the course evaluation. It really helps us to understand what is being done well, and how we can improve both the course and our teaching.

# %% [markdown]
# License: [Creative Commons (CC BY-NC-SA 4.0)](https://creativecommons.org/)
